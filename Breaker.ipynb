# %%
from campy.gui.events.timer import pause
from breakoutgraphics import BreakoutGraphics

FRAME_RATE = 1000 / 120   # 120 frames per second.
NUM_LIVES = 10


def main():
    graphics = BreakoutGraphics()
    lives = NUM_LIVES
    while True:
        if lives <= 0:
            break
        else:
            pause(FRAME_RATE)
            graphics.move()
            graphics.reflect()
#             graphics.remove_brick()
            if graphics.ball.y >= graphics.window.height:
                lives -= 1
                graphics.reset_ball()
                graphics.switch_off()
            if lives <= 0:
                break
            finished = graphics.finished()
            if finished:
                break


if __name__ == '__main__':
    main()
# Out:
# 0.30179708488775303
# 0.2527928367710758
# 0.7420059872196427
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-1-e4d1629ab62f> in <module>
#      29
#      30 if __name__ == '__main__':
# ---> 31     main()
#
# <ipython-input-1-e4d1629ab62f> in main()
#      13             break
#      14         else:
# ---> 15             pause(FRAME_RATE)
#      16             graphics.move()
#      17             graphics.reflect()
#
# ~\anaconda3\lib\site-packages\campy\gui\events\timer.py in pause(milliseconds, step, time_fn, sleep_fn)
#      50     # Loop until at least this much time has passed.
#      51     while time_fn() - start < milliseconds / 1000:
# ---> 52         _platform.Platform().event_pump_one()
#      53         events += 1
#      54         if step:
#
# ~\anaconda3\lib\site-packages\campy\private\backends\tk\backend_tk.py in event_pump_one(self)
#     793     def event_pump_one(self):
#     794         # Forcibly process queued tasks, but don't process newly queued ones.
# --> 795         self._root.update_idletasks()
#     796         self._root.dooneevent(DONT_WAIT)
#     797
#
# ~\anaconda3\lib\tkinter\__init__.py in update_idletasks(self)
#    1309         will update the display of windows but not process events caused by
#    1310         the user."""
# -> 1311         self.tk.call('update', 'idletasks')
#    1312
#    1313     def bindtags(self, tagList=None):
#
# TclError: can't invoke "update" command: application has been destroyed
